# %% [markdown]
# ### Supplemental Reading
#
# - Class I:
#   - Programming in Python 3: A Complete Introduction to the Python Language, Second Edition. Available through NYU Libraries [here](https://search.library.nyu.edu/permalink/01NYU_INST/1eeerc1/cdi_askewsholts_vlebooks_9780321699879).
#   - Practical Python Data Wrangling and Data Quality. Available through NYU Libraries [here](https://search.library.nyu.edu/permalink/01NYU_INST/1eeerc1/cdi_proquest_ebookcentralchapters_6822218_44_55).
#   - Head First Python.  Available through the NYU Libraries [here](https://search.library.nyu.edu/permalink/01NYU_INST/1d6v258/alma990097970930107871).
# - Class II:
#   - Python for Data Analysis. Available through NYU libraries and the authoritative resource for Pandas [here](https://search.library.nyu.edu/permalink/01NYU_INST/1d6v258/alma990084111580107871).
#   - Data Science for Business. Available through NYU libraries, written by NYU faculty and an excellent introduction to many standard applications of data science for business [here](https://search.library.nyu.edu/permalink/01NYU_INST/1d6v258/alma990040225930107876)
#
#
#
# - Class VI:
#   - Hands on Machine Learning. Available through NYU libraries -- chapter 2 end to end walkthrough covers much of the ground of our upcoming work with predictive models and scikitlearn as well as EDA and feature engineering. [here](https://search.library.nyu.edu/permalink/01NYU_INST/1e86n5m/cdi_proquest_ebookcentralchapters_30168989_18_29_
#   -

# %% [markdown]
# ### Accessing Data with API's
#
# **OBJECTIVES**
#
# - Use the `requests` library to access data from API's
# - Use wrapper libraries to extract data from API's
# - Structure data from API calls as `DataFrame` objects

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import requests

# %% [markdown]
# ### Pokémon API
#
# ![](images/logan_poke.png)
#
# To start, let's explore the Pokémon API [here](https://pokeapi.co/).  This API does not require an API key and is free to use.  Our typical workflow with an API is as follows:
#
# - Use documentation to understand how to format the url
# - Make a request of the url -- `requests.get(url)`
# - Make sure request worked -- should be a 200 response code
# - Turn the request into a Python data structure -- `request.json()`
# - Extract data we need using dictionary and list knowledge

# %%
#url for pokemon

# %%
#make a request

# %%
#check that it worked

# %%
#turn into json

# %%
#extract abilities as a list

# %%
#consider how you would organize this data as a table/DataFrame
#what would the columns be and what would each row represent

# %% [markdown]
# ### Last FM
#
# The API for Last FM requires an API Key.  Head over [here](https://www.last.fm/api/authentication) to signup for yours -- it should be instantaneous.

# %%
base_url = ''

# %%
#examine the response

# %%
#extract the headline

# %% [markdown]
# **Exercise**
#
# Use the `album.GetInfo` method [docs](https://www.last.fm/api/show/album.getInfo) to get information about an album of your choosing.

# %% [markdown]
# #### Similar Songs
#
# Use the get similar endpoint [here](https://www.last.fm/api/show/track.getSimilar) to extract a list of 20 songs similar to the band Catherine Wheel's song Black Metallic.  Format the results as a DataFrame with appropriate column names.

# %% [markdown]
# **PROBLEM**
#
# Perhaps you need some new music to listen to while you code.  Let's make a list of 100 songs to explore as follows:
#
# - Identify 10 artists that you and your partner appreciate
# - Find similar artists to these 10 using the LastFM api
# - Look up these artists top songs
# - Create a playlist that contains the top song of each similar artist

# %%
ten_artists = []

# %% [markdown]
# ### Finding an API
#
# There are many different API's with interesting data out there.  Your goal is to find an API of interest and make a request of the API, structuring the result as a DataFrame.  Record your findings [here](https://forms.gle/NiZ45f3E1bYXm8vY8).
